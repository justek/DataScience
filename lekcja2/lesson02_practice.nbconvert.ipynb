# %% [markdown]
# # Lesson 02 Practice
# Autor: Justyna Pietrzyńska
# Cel: Nauka Jupyter Notebook.

# %%
# importy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print("Biblioteki zaimportowane.")
# Out:
# Biblioteki zaimportowane.

# %%
RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)
print(f"Random seed ustawiony na {RANDOM_STATE}.")
# Out:
# Random seed ustawiony na 42.

# %%
#dataset
df = pd.DataFrame({
    "Age": np.random.randint(18, 65, 100),
    "Salary": np.random.randint(3000, 15000, 100),
    "Experience": np.random.randint(0, 30, 100)
})

print("Dataset został utworzony.")
# Out:
# Dataset został utworzony.

# %%
print("=== HEAD ===")
print(df.head())

print("\n=== INFO ===")
df.info()

print("\n=== DESCRIBE ===")
print(df.describe())
# Out:
# === HEAD ===
#    Age  Salary  Experience
# 0   56    5695           2
# 1   46   12687          16
# 2   32    8258           4
# 3   60    8618          16
# 4   25    9736          23
#
# === INFO ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Age         100 non-null    int64
#  1   Salary      100 non-null    int64
#  2   Experience  100 non-null    int64
# dtypes: int64(3)
# memory usage: 2.5 KB
#
# === DESCRIBE ===
#              Age        Salary  Experience
# count  100.00000    100.000000  100.000000
# mean    40.88000   9141.760000   14.000000
# std     13.99082   3331.023925    9.363587
# min     18.00000   3206.000000    0.000000
# 25%     30.50000   6288.500000    5.000000
# 50%     41.00000   9101.500000   15.000000
# 75%     53.25000  11924.750000   22.000000
# max     64.00000  14935.000000   29.000000
