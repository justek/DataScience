# %%
import os

project_name = "sales_analysis"

folders = [
    "data/raw",
    "data/processed",
    "notebooks",
    "src",
    "models",
    "reports"
]

# Tworzenie folderów
for folder in folders:
    os.makedirs(os.path.join(project_name, folder), exist_ok=True)

# README.md
with open(os.path.join(project_name, "README.md"), "w") as f:
    f.write("# Sales Analysis\n\n")
    f.write("Projekt do analizy danych sprzedażowych.\n")

# .gitignore
with open(os.path.join(project_name, ".gitignore"), "w") as f:
    f.write("data/raw/\n")

print("Struktura projektu została utworzona.")
# Out:
# Struktura projektu została utworzona.
