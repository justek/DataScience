# %% [markdown]
# # Lesson 02 Practice
# Autor: Justyna Pietrzyńska
# Cel: Nauka Jupyter Notebook.

# %%
# importy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print("Biblioteki zaimportowane.")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Biblioteki zaimportowane.

# %%
RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)
print(f"Random seed ustawiony na {RANDOM_STATE}.")
# Out:
# Random seed ustawiony na 42.

# %%
#dataset
df = pd.DataFrame({
    "Age": np.random.randint(18, 65, 100),
    "Salary": np.random.randint(3000, 15000, 100),
    "Experience": np.random.randint(0, 30, 100)
})

print("Dataset został utworzony.")
# Out:
# Dataset został utworzony.

# %%
print("=== HEAD ===")
print(df.head())

print("\n=== INFO ===")
df.info()

print("\n=== DESCRIBE ===")
print(df.describe())
# Out:
# === HEAD ===
#    Age  Salary  Experience
# 0   37    8596          13
# 1   41    8801          29
# 2   50    5806          19
# 3   41    3537           4
# 4   28    8986          11
#
# === INFO ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Age         100 non-null    int64
#  1   Salary      100 non-null    int64
#  2   Experience  100 non-null    int64
# dtypes: int64(3)
# memory usage: 2.5 KB
#
# === DESCRIBE ===
#               Age        Salary  Experience
# count  100.000000    100.000000  100.000000
# mean    43.680000   8718.610000   14.340000
# std     12.570512   3324.608767    9.442243
# min     19.000000   3004.000000    0.000000
# 25%     35.750000   6025.750000    5.500000
# 50%     45.500000   8658.000000   15.000000
# 75%     52.000000  11206.750000   23.000000
# max     64.000000  14928.000000   29.000000
